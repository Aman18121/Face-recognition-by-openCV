# %%
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\aman yadav\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow<2.19,>=2.18 in c:\users\aman yadav\anaconda3\lib\site-packages (from tf-keras) (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (4.21.12)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.41.2)
# Requirement already satisfied: rich in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.1.0)

# %%
# !pip install opencv-python deepface
# Out:
# Requirement already satisfied: opencv-python in c:\users\aman yadav\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: deepface in c:\users\aman yadav\anaconda3\lib\site-packages (0.0.93)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: requests>=2.27.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (2.1.4)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (10.2.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (2.18.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (3.8.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (2.2.5)
# Requirement already satisfied: flask-cors>=4.0.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (5.0.0)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from deepface) (23.0.0)
# Requirement already satisfied: termcolor in c:\users\aman yadav\anaconda3\lib\site-packages (from fire>=0.4.0->deepface) (2.5.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: beautifulsoup4 in c:\users\aman yadav\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\aman yadav\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: packaging in c:\users\aman yadav\anaconda3\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.1)
# Requirement already satisfied: absl-py in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (2.1.0)
# Requirement already satisfied: rich in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (13.3.5)
# Requirement already satisfied: namex in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (3.13.0)
# Requirement already satisfied: optree in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\aman yadav\anaconda3\lib\site-packages (from keras>=2.2.0->deepface) (0.4.1)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\aman yadav\anaconda3\lib\site-packages (from mtcnn>=0.1.0->deepface) (4.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests>=2.27.1->deepface) (2025.1.31)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (4.21.12)
# Requirement already satisfied: setuptools in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (2.18.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: colorama in c:\users\aman yadav\anaconda3\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aman yadav\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\aman yadav\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from rich->keras>=2.2.0->deepface) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.41.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aman yadav\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\aman yadav\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow>=1.9.0->deepface) (0.7.2)

# %%
# !pip install cmake dlib face-recognition

# %%
# Out:
# WARNING:tensorflow:From C:\Users\Aman Yadav\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import cv2
import threading
from deepface import DeepFace

# Open webcam
capture = cv2.VideoCapture(0, cv2.CAP_DSHOW)
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 800)
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 800)


counter = 0
match = False


reference = cv2.imread("Open.CV Sample picture.jpeg")

def face_match(frame):
    global match
    try:
        if DeepFace.verify(frame, reference.copy())['verified']:
            match = True
        else:
            match = False
    except ValueError:
        match = False
    except Exception as e:
        print(f"Error: {e}")
        match = False

while True:
    ret, frame = capture.read()
    
    if not ret:
        continue  
    
    if counter % 30 == 0:  
        try:
            threading.Thread(target=face_match, args=(frame.copy(),)).start()
        except ValueError:
            pass
    
    counter += 1
    
   
    if match:
        cv2.putText(frame, "Image Matched!!", (800//2, 800//2), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
    else:
        cv2.putText(frame, "No Match", (800//2, 800//2), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 3)
    
    cv2.imshow("Webcam Feed", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break

capture.release()
cv2.destroyAllWindows()
